# %% [markdown]
# ### Project 2

# %% [markdown]
# #### Multi Layer Perceptron (MLP) trained on the Dataset 1

# %%
#Importing essential libraries
from sklearn.datasets import fetch_openml

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os 
import cv2
import random 
import math
import pandas as pd

from datetime import datetime

from sklearn import metrics
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D,Conv2D,MaxPooling1D,Flatten,Dense,Dropout,BatchNormalization, GRU, LSTM, RNN
from tensorflow.keras import regularizers as reg

import tensorflow as tf
from tensorflow import keras
import pickle

# %%
pickle_in = open("X_train_T1.pickle","rb")
X_train = pickle.load(pickle_in)

pickle_in = open("y_train_T1.pickle","rb")
y_train = pickle.load(pickle_in)

pickle_in = open("X_test_T1.pickle","rb")
X_test = pickle.load(pickle_in)

# %%
print('X_train :', X_train.shape)
print('y_train :', y_train.shape)
print('X_test :', X_test.shape)
# Out:
# X_train : (4431, 441)
# y_train : (4431,)
# X_test : (4520, 441)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
scaler.transform(X_train)
scaler.transform(X_test)

# %%
X_train[:]
# Out:
#             sensor_1_sum  sensor_1_mean  sensor_1_std   sensor_1_var  \
# segment_id
# 1136037770      -96621.0      -1.610323    303.096099   91867.245099
# 1969647810       85569.0       1.426126    438.360560  192159.980413
# 1895879680      150278.0       2.504592    241.575415   58358.681050
# 2068207140      129950.0       2.165797    221.967825   49269.715377
# 192955606         4429.0       0.073815    261.695935   68484.762635
# ...                  ...            ...           ...            ...
# 873340274        54405.0       0.906735    613.427301  376293.054135
# 1297437712      476221.0       7.936884    649.089618  421317.332733
# 694853998        85261.0       1.420993    110.942596   12308.259562
# 1886987043       54350.0       0.905818    478.852581  229299.794013
# 1100632800     -248575.0      -4.142848    272.632730   74328.605478
#
#             sensor_1_max  sensor_1_min  sensor_1_median  sensor_1_skew  \
# segment_id
# 1136037770        1353.0       -1421.0              0.0      -0.057494
# 1969647810        2197.0       -2005.0              0.0      -0.001189
# 1895879680        1148.0       -1115.0              0.0       0.071632
# 2068207140        1254.0       -1025.0              0.0       0.123639
# 192955606         1114.0       -1190.0              0.0       0.006594
# ...                  ...           ...              ...            ...
# 873340274         2916.0       -2610.0              0.0      -0.003413
# 1297437712        4498.0       -3654.0              0.0       0.113867
# 694853998          557.0        -753.0              0.0      -0.060527
# 1886987043        3938.0       -3555.0              0.0       0.028062
# 1100632800        2063.0       -1404.0              0.0       0.022485
#
#             sensor_1_mad  sensor_1_kurtosis  ...  sensor_10_fft_real_median  \
# segment_id                                   ...
# 1136037770    238.836278           0.247736  ...                 383.981464
# 1969647810    334.894305           1.177624  ...                 122.448931
# 1895879680    189.198970           0.567813  ...                 139.338402
# 2068207140    171.285870           1.079660  ...                 -47.376444
# 192955606     205.913478           0.274037  ...                 157.846818
# ...                  ...                ...  ...                        ...
# 873340274     487.948374           0.168746  ...                -867.393367
# 1297437712    508.895214           0.695682  ...                 803.989124
# 694853998      86.101013           1.005580  ...                -163.463548
# 1886987043    359.875923           2.278329  ...                 -50.159215
# 1100632800    211.399086           1.326928  ...                 129.164339
#
#             sensor_10_fft_real_skew  sensor_10_fft_real_kurtosis  \
# segment_id
# 1136037770                -3.691093                   400.282146
# 1969647810                 0.555212                    54.561405
# 1895879680                -1.351932                    87.429275
# 2068207140                 0.238320                    67.970726
# 192955606                 -0.469491                    40.417556
# ...                             ...                          ...
# 873340274                  0.732382                    84.940470
# 1297437712                -0.206159                    35.867929
# 694853998                 -0.618217                    35.455675
# 1886987043                 0.448246                    38.864099
# 1100632800                -7.790700                   708.948633
#
#             sensor_10_fft_imag_mean  sensor_10_fft_imag_std  \
# segment_id
# 1136037770            -2.793921e-13           102524.406272
# 1969647810             6.208714e-14           161340.726460
# 1895879680             0.000000e+00            88121.930122
# 2068207140             1.086525e-13            89160.395448
# 192955606              3.104357e-14            97922.932107
# ...                             ...                     ...
# 873340274              6.829585e-13           184932.188095
# 1297437712             6.208714e-14           223710.154467
# 694853998              6.208714e-14            43975.069801
# 1886987043             6.984803e-14           102593.125398
# 1100632800            -2.483485e-13           135322.887863
#
#             sensor_10_fft_imag_max  sensor_10_fft_imag_min  \
# segment_id
# 1136037770            4.606198e+06           -4.606198e+06
# 1969647810            3.233464e+06           -3.233464e+06
# 1895879680            2.360908e+06           -2.360908e+06
# 2068207140            1.493266e+06           -1.493266e+06
# 192955606             1.579777e+06           -1.579777e+06
# ...                            ...                     ...
# 873340274             5.552329e+06           -5.552329e+06
# 1297437712            3.573250e+06           -3.573250e+06
# 694853998             6.260993e+05           -6.260993e+05
# 1886987043            1.946644e+06           -1.946644e+06
# 1100632800            9.403574e+06           -9.403574e+06
#
#             sensor_10_fft_imag_median  sensor_10_fft_imag_skew  \
# segment_id
# 1136037770               6.730261e-11            -1.266921e-15
# 1969647810               4.365575e-11             1.625434e-16
# 1895879680              -3.365130e-11             1.870470e-16
# 2068207140              -4.365575e-11             1.926263e-16
# 192955606               -3.819878e-11            -9.087789e-17
# ...                               ...                      ...
# 873340274               -3.637979e-11             2.374579e-16
# 1297437712               1.091394e-10            -4.877916e-17
# 694853998               -3.365130e-11             0.000000e+00
# 1886987043              -9.731593e-11             2.133637e-16
# 1100632800              -2.773959e-10            -1.763062e-15
#
#             sensor_10_fft_imag_kurtosis
# segment_id
# 1136037770                   391.330005
# 1969647810                    48.888978
# 1895879680                    78.472764
# 2068207140                    39.995383
# 192955606                     41.547803
# ...                                 ...
# 873340274                    100.279600
# 1297437712                    37.624950
# 694853998                     30.797139
# 1886987043                    40.800619
# 1100632800                  1327.630688
#
# [4431 rows x 441 columns]

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(4431, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
#sgd = SGD(learning_rate=0.001)
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
early_stopping_monitor = EarlyStopping(patience=10)
callbacks_list = [early_stopping_monitor]
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 4431)              1958502
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               1134592
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 3,224,935
# Trainable params: 3,224,935
# Non-trainable params: 0
# _________________________________________________________________

# %%
NN_model.fit(X_train, y_train, epochs=250, batch_size=10, validation_split = 0.05 , callbacks=callbacks_list )
# Out:
# Epoch 1/250
# 421/421 [==============================] - 7s 17ms/step - loss: 14507945.0000 - mean_absolute_error: 14507945.0000 - val_loss: 11409279.0000 - val_mean_absolute_error: 11409279.0000
# Epoch 2/250
# 421/421 [==============================] - 7s 16ms/step - loss: 10772617.0000 - mean_absolute_error: 10772617.0000 - val_loss: 10277386.0000 - val_mean_absolute_error: 10277386.0000
# Epoch 3/250
# 421/421 [==============================] - 7s 17ms/step - loss: 9298641.0000 - mean_absolute_error: 9298641.0000 - val_loss: 9550239.0000 - val_mean_absolute_error: 9550237.0000
# Epoch 4/250
# 421/421 [==============================] - 7s 17ms/step - loss: 8933646.0000 - mean_absolute_error: 8933646.0000 - val_loss: 12072620.0000 - val_mean_absolute_error: 12072618.0000- ETA: 2s - loss: 8728923.0000
# Epoch 5/250
# 421/421 [==============================] - 7s 16ms/step - loss: 8104673.0000 - mean_absolute_error: 8104673.0000 - val_loss: 7562833.5000 - val_mean_absolute_error: 7562833.5000
# Epoch 6/250
# 421/421 [==============================] - 7s 17ms/step - loss: 8029817.5000 - mean_absolute_error: 8029817.5000 - val_loss: 8504560.0000 - val_mean_absolute_error: 8504560.0000
# Epoch 7/250
# 421/421 [==============================] - 7s 16ms/step - loss: 7593768.0000 - mean_absolute_error: 7593768.0000 - val_loss: 8883364.0000 - val_mean_absolute_error: 8883364.0000
# Epoch 8/250
# 421/421 [==============================] - 6s 15ms/step - loss: 7308207.0000 - mean_absolute_error: 7308207.5000 - val_loss: 7237730.5000 - val_mean_absolute_error: 7237730.5000
# Epoch 9/250
# 421/421 [==============================] - 6s 15ms/step - loss: 7095223.5000 - mean_absolute_error: 7095223.5000 - val_loss: 7678474.0000 - val_mean_absolute_error: 7678474.0000
# Epoch 10/250
# 421/421 [==============================] - 6s 15ms/step - loss: 7222290.0000 - mean_absolute_error: 7222290.0000 - val_loss: 7744270.5000 - val_mean_absolute_error: 7744270.5000
# Epoch 11/250
# 421/421 [==============================] - 7s 16ms/step - loss: 6802138.0000 - mean_absolute_error: 6802138.0000 - val_loss: 6844781.5000 - val_mean_absolute_error: 6844781.5000
# Epoch 12/250
# 421/421 [==============================] - 6s 15ms/step - loss: 6610017.0000 - mean_absolute_error: 6610017.0000 - val_loss: 7204837.5000 - val_mean_absolute_error: 7204837.5000
# Epoch 13/250
# 421/421 [==============================] - 7s 16ms/step - loss: 6774294.5000 - mean_absolute_error: 6774294.5000 - val_loss: 7197726.0000 - val_mean_absolute_error: 7197726.0000
# Epoch 14/250
# 421/421 [==============================] - 7s 16ms/step - loss: 6432048.5000 - mean_absolute_error: 6432048.5000 - val_loss: 6666118.0000 - val_mean_absolute_error: 6666118.0000
# Epoch 15/250
# 421/421 [==============================] - 6s 15ms/step - loss: 6347082.0000 - mean_absolute_error: 6347082.0000 - val_loss: 7045364.0000 - val_mean_absolute_error: 7045364.0000
# Epoch 16/250
# 421/421 [==============================] - 6s 15ms/step - loss: 6216032.0000 - mean_absolute_error: 6216032.0000 - val_loss: 6202390.5000 - val_mean_absolute_error: 6202390.5000
# Epoch 17/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5967109.0000 - mean_absolute_error: 5967109.0000 - val_loss: 7162970.5000 - val_mean_absolute_error: 7162970.5000
# Epoch 18/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5874509.5000 - mean_absolute_error: 5874509.5000 - val_loss: 7963508.5000 - val_mean_absolute_error: 7963508.5000ETA: 0s - loss: 5876814.5000 - mean_absolute_error: 5876814.500
# Epoch 19/250
# 421/421 [==============================] - 7s 18ms/step - loss: 5882911.5000 - mean_absolute_error: 5882911.5000 - val_loss: 6501208.0000 - val_mean_absolute_error: 6501208.0000
# Epoch 20/250
# 421/421 [==============================] - 8s 18ms/step - loss: 5828274.5000 - mean_absolute_error: 5828274.5000 - val_loss: 6359101.0000 - val_mean_absolute_error: 6359101.0000
# Epoch 21/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5491913.0000 - mean_absolute_error: 5491913.0000 - val_loss: 5862512.5000 - val_mean_absolute_error: 5862512.5000
# Epoch 22/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5495028.5000 - mean_absolute_error: 5495028.5000 - val_loss: 6199934.5000 - val_mean_absolute_error: 6199933.5000
# Epoch 23/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5454778.0000 - mean_absolute_error: 5454778.5000 - val_loss: 6032135.0000 - val_mean_absolute_error: 6032135.0000
# Epoch 24/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5460149.0000 - mean_absolute_error: 5460149.0000 - val_loss: 6306638.5000 - val_mean_absolute_error: 6306638.5000
# Epoch 25/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5127705.0000 - mean_absolute_error: 5127705.0000 - val_loss: 5964886.0000 - val_mean_absolute_error: 5964886.0000
# Epoch 26/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5087434.5000 - mean_absolute_error: 5087434.5000 - val_loss: 5596847.5000 - val_mean_absolute_error: 5596847.5000
# Epoch 27/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5126454.0000 - mean_absolute_error: 5126454.0000 - val_loss: 6240456.5000 - val_mean_absolute_error: 6240456.5000
# Epoch 28/250
# 421/421 [==============================] - 7s 17ms/step - loss: 5095934.0000 - mean_absolute_error: 5095934.0000 - val_loss: 5868578.5000 - val_mean_absolute_error: 5868578.5000
# Epoch 29/250
# 421/421 [==============================] - 8s 19ms/step - loss: 4942835.0000 - mean_absolute_error: 4942835.0000 - val_loss: 5577682.0000 - val_mean_absolute_error: 5577682.0000
# Epoch 30/250
# 421/421 [==============================] - 8s 19ms/step - loss: 4791254.0000 - mean_absolute_error: 4791254.0000 - val_loss: 5906320.5000 - val_mean_absolute_error: 5906320.5000
# Epoch 31/250
# 421/421 [==============================] - 8s 19ms/step - loss: 4703254.5000 - mean_absolute_error: 4703254.5000 - val_loss: 6396504.0000 - val_mean_absolute_error: 6396504.0000
# Epoch 32/250
# 421/421 [==============================] - 7s 16ms/step - loss: 4661898.0000 - mean_absolute_error: 4661898.0000 - val_loss: 5405560.5000 - val_mean_absolute_error: 5405560.5000
# Epoch 33/250
# 421/421 [==============================] - 8s 19ms/step - loss: 4591027.5000 - mean_absolute_error: 4591027.5000 - val_loss: 5788865.0000 - val_mean_absolute_error: 5788865.0000
# Epoch 34/250
# 421/421 [==============================] - 7s 17ms/step - loss: 4627923.0000 - mean_absolute_error: 4627923.0000 - val_loss: 5234451.0000 - val_mean_absolute_error: 5234451.0000
# Epoch 35/250
# 421/421 [==============================] - 7s 18ms/step - loss: 4439002.5000 - mean_absolute_error: 4439002.5000 - val_loss: 5184493.5000 - val_mean_absolute_error: 5184493.5000
# Epoch 36/250
# 421/421 [==============================] - 7s 17ms/step - loss: 4453159.0000 - mean_absolute_error: 4453159.0000 - val_loss: 6708375.0000 - val_mean_absolute_error: 6708375.5000
# Epoch 37/250
# 421/421 [==============================] - 8s 18ms/step - loss: 4455275.0000 - mean_absolute_error: 4455275.0000 - val_loss: 5301595.5000 - val_mean_absolute_error: 5301595.5000
# Epoch 38/250
# 421/421 [==============================] - 8s 19ms/step - loss: 4332442.0000 - mean_absolute_error: 4332442.0000 - val_loss: 5740673.5000 - val_mean_absolute_error: 5740673.5000
# Epoch 39/250
# 421/421 [==============================] - 7s 18ms/step - loss: 4173560.7500 - mean_absolute_error: 4173560.7500 - val_loss: 5879630.0000 - val_mean_absolute_error: 5879630.0000
# Epoch 40/250
# 421/421 [==============================] - 7s 16ms/step - loss: 4312357.5000 - mean_absolute_error: 4312357.5000 - val_loss: 4936293.0000 - val_mean_absolute_error: 4936293.0000
# Epoch 41/250
# 421/421 [==============================] - 7s 17ms/step - loss: 4077509.0000 - mean_absolute_error: 4077509.0000 - val_loss: 5208339.0000 - val_mean_absolute_error: 5208339.0000
# Epoch 42/250
# 421/421 [==============================] - 7s 17ms/step - loss: 3987928.2500 - mean_absolute_error: 3987928.2500 - val_loss: 4976597.0000 - val_mean_absolute_error: 4976597.0000
# Epoch 43/250
# 421/421 [==============================] - 7s 17ms/step - loss: 3983679.0000 - mean_absolute_error: 3983679.2500 - val_loss: 5707318.0000 - val_mean_absolute_error: 5707318.0000
# Epoch 44/250
# 421/421 [==============================] - 7s 17ms/step - loss: 4142975.0000 - mean_absolute_error: 4142975.0000 - val_loss: 5665534.5000 - val_mean_absolute_error: 5665534.5000
# Epoch 45/250
# 421/421 [==============================] - 7s 17ms/step - loss: 4018313.2500 - mean_absolute_error: 4018313.2500 - val_loss: 5188396.0000 - val_mean_absolute_error: 5188396.0000
# Epoch 46/250
# 421/421 [==============================] - 7s 17ms/step - loss: 3965202.5000 - mean_absolute_error: 3965202.5000 - val_loss: 5112324.0000 - val_mean_absolute_error: 5112324.0000
# Epoch 47/250
# 421/421 [==============================] - 7s 17ms/step - loss: 3898341.2500 - mean_absolute_error: 3898341.2500 - val_loss: 5508219.5000 - val_mean_absolute_error: 5508219.5000
# Epoch 48/250
# 421/421 [==============================] - 7s 17ms/step - loss: 3819849.7500 - mean_absolute_error: 3819850.0000 - val_loss: 5257134.5000 - val_mean_absolute_error: 5257134.5000
# Epoch 49/250
# 421/421 [==============================] - 8s 20ms/step - loss: 3808575.0000 - mean_absolute_error: 3808575.2500 - val_loss: 5329838.5000 - val_mean_absolute_error: 5329838.5000
# Epoch 50/250
# 421/421 [==============================] - 7s 18ms/step - loss: 3765573.5000 - mean_absolute_error: 3765573.5000 - val_loss: 4988288.0000 - val_mean_absolute_error: 4988288.0000

# %%
predictions = NN_model.predict(X_test)
print(predictions)
# Out:
# [[11950209.]
#  [36945364.]
#  [13477431.]
#  ...
#  [13954023.]
#  [43990680.]
#  [22820154.]]

# %%
predictions.shape
# Out:
# (4520, 1)

# %%
submission = pd.DataFrame()
submission['segment_id'] = X_test.index
submission['time_to_eruption'] = predictions
submission.to_csv('submission_MLP2.csv', header=True, index=False)
